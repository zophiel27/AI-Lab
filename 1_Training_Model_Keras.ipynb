# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

df = pd.read_csv('diabetes.csv')
print(df.shape)
df.describe()
target_column = ['Outcome']
predictors = list(set(list(df.columns))-set(target_column))
list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()

X = df[predictors].values
y = df[target_column].values
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)

# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
count_classes = y_test.shape[1]
print(count_classes)

model = Sequential()
model.add(Dense(500, activation='relu', input_dim=8))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# build the model
model.fit(X_train, y_train, epochs=20)

pred_train= model.predict(X_train)
scores = model.evaluate(X_train, y_train, verbose=0)
print('Accuracy on training data: {}% \n Error on training data: {}'.format(scores[1], 1 - scores[1]))
pred_test= model.predict(X_test)
scores2 = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy on test data: {}% \n Error on test data:{}'.format(scores2[1], 1 - scores2[1]))
# Out:
# (768, 9)
# (537, 8)
# (231, 8)
# 2
# Epoch 1/20
# 17/17 [==============================] - 1s 5ms/step - loss: 0.6538 - accuracy: 0.6536
# Epoch 2/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6183 - accuracy: 0.6723
# Epoch 3/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5963 - accuracy: 0.6797
# Epoch 4/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5636 - accuracy: 0.7225
# Epoch 5/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5431 - accuracy: 0.7169
# Epoch 6/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5521 - accuracy: 0.7430
# Epoch 7/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.7635
# Epoch 8/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5054 - accuracy: 0.7561
# Epoch 9/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4854 - accuracy: 0.7747
# Epoch 10/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4782 - accuracy: 0.7803
# Epoch 11/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4682 - accuracy: 0.7784
# Epoch 12/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4584 - accuracy: 0.7821
# Epoch 13/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4874 - accuracy: 0.7579
# Epoch 14/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4972 - accuracy: 0.7635
# Epoch 15/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4795 - accuracy: 0.7579
# Epoch 16/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4634 - accuracy: 0.7858
# Epoch 17/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.8026
# Epoch 18/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.7784
# Epoch 19/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4468 - accuracy: 0.7970
# Epoch 20/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4437 - accuracy: 0.7840
# 17/17 [==============================] - 0s 2ms/step
# Accuracy on training data: 0.80633145570755%
#  Error on training data: 0.19366854429244995
# 8/8 [==============================] - 0s 2ms/step
# Accuracy on test data: 0.7532467246055603%
#  Error on test data:0.2467532753944397
